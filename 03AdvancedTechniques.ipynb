# %% [markdown]
# # Self-Consistency and Multiple Paths of Reasoning
#
# LLMs can sometimes generate inconsistent or unreliable outputs. To mitigate this, techniques such as employing multiple reasoning paths, aggregating results, and implementing consistency checks are used.

# %%
from langchain_ollama import ChatOllama
from langchain.prompts import PromptTemplate

import random
from collections import Counter

import re
from langchain.output_parsers import RegexParser

# %%
llm = ChatOllama(model="llama3.2")

# %% [markdown]
# ## Generating Multiple Reasoning Paths

# %%
def generate_multiple_paths(problem, num_paths=3):
    """
    Generate multiple reasoning paths for a given problem.
    
    Args:
    problem (str): The problem statement.
    num_paths (int): Number of reasoning paths to generate.
    
    Returns:
    list: A list of generated reasoning paths.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "path_number"],
        template="""Solve the following problem using a unique approach. This is reasoning path {path_number}.
        Problem: {problem}
        Reasoning path {path_number}:"""
    )

    paths = []
    for i in range(num_paths):
        chain = prompt_template | llm
        response = chain.invoke({"problem": problem, "path_number": i+1}).content
        paths.append(response)
    
    return paths

# %%
problem = "A ball is thrown in upwards direction with an initial velocity of 20 m/s. How high will it go?"
paths = generate_multiple_paths(problem)

for i, path in enumerate(paths, 1):
    print(f"Path {i}:\n{path}\n")
# Out:
# Path 1:
# This problem can be solved by considering the motion of the ball under the sole influence of gravity, which acts to slow down the ball's upward motion and eventually bring it back down to its starting point.
#
# Here's a unique approach:
#
# Imagine that the ball is not moving vertically, but instead is being pulled sideways towards you by an invisible force. This force would be equivalent in magnitude to the horizontal component of the initial velocity (20 m/s), but directed downwards. The downward force would slow down the ball horizontally, just like gravity slows down the ball's vertical motion.
#
# As the ball moves upwards initially, it would continue to move sideways at a constant speed due to this invisible force. Once the ball reaches its maximum height, the horizontal component of the velocity would be zero (since there's no horizontal motion), but the downward force would still be present.
#
# Now, imagine that instead of moving horizontally, the ball was somehow "unanchored" and could move freely in any direction. In this case, the invisible force would now affect the ball vertically, causing it to accelerate downwards at a rate of 9.8 m/s^2 (the acceleration due to gravity).
#
# Since we know that the initial upward velocity is 20 m/s, we can calculate the time it takes for the ball to reach its maximum height using the following equation:
#
# v = u + gt
#
# where v is the final vertical velocity (0 m/s at the maximum height), u is the initial vertical velocity (-9.8 m/s, since it's initially downwards), g is the acceleration due to gravity (9.8 m/s^2), and t is the time.
#
# Rearranging the equation to solve for t, we get:
#
# t = -u/g
#
# Plugging in the values, we get:
#
# t = 20/9.8 ≈ 2.04 seconds
#
# Now that we have the time it takes for the ball to reach its maximum height, we can calculate the maximum height using the following equation:
#
# h = u^2 / (2g)
#
# where h is the maximum height, u is the initial velocity (20 m/s), and g is the acceleration due to gravity (9.8 m/s^2).
#
# Plugging in the values, we get:
#
# h ≈ 200/19.6 ≈ 10.22 meters
#
# So, the ball will reach a height of approximately 10.22 meters above its initial position.
#
# This unique approach involves visualizing the ball's motion as being influenced by an invisible force and then using this visualization to calculate the maximum height it reaches.
#
# Path 2:
# The final answer is not provided, but I can guide you through the reasoning process using a unique approach.
#
# To find the maximum height reached by the ball, we can use the concept of time of flight and the relationship between velocity, acceleration, and displacement. Here's an alternative approach:
#
# 1. **Model the motion as a sinusoidal function**: Since the ball is thrown upwards with an initial velocity, its upward motion can be modeled using a sinusoidal function. The maximum height reached by the ball will occur when the cosine of the time (t) is at its maximum value, which is 1.
#
# H = v0*t - (1/2)*g*t^2
#
# where H is the displacement (height), v0 is the initial velocity, g is the acceleration due to gravity (-9.8 m/s^2).
#
# 2. **Use the time of flight equation**: The total time of flight for a ball thrown upwards can be calculated using the following equation:
#
# T = 2*v0/g
#
# where T is the time of flight.
#
# 3. **Find the maximum height**: Substitute the expression for T into the equation for H:
#
# H_max = v0*T/2 - (1/2)*g*(v0*T)^2 / (4*g)
#
# Simplifying this expression gives:
#
# H_max = v0^2/(2*g)
#
# Substituting the given initial velocity of 20 m/s and the acceleration due to gravity, we get:
#
# H_max = (20^2) / (2 * -9.8)
# = 400 / (-19.6)
# ≈ 20.41 meters
#
# This is the maximum height reached by the ball.
#
# The provided reasoning path does not contain enough information for me to provide a final answer.
#
# Path 3:
# This problem seems to be more related to physics and motion, rather than code development. However, I'll provide a solution using a unique approach by simulating the motion of the ball over time.
#
# **Approach:** We can model the ball's motion as an object under constant acceleration due to gravity (g = -9.81 m/s^2). We'll use numerical integration to solve for the maximum height reached by the ball.
#
# Let's assume we have a step-by-step process:
#
# 1. Initialize variables:
# 	* Initial velocity (v0) = 20 m/s
# 	* Gravity acceleration (g) = -9.81 m/s^2
# 	* Time step (dt) = 0.01 s
# 2. Calculate the acceleration at each time step:
# 	* a = v0 * dt + g * dt^2
# 3. Update the velocity and position using Euler's method or other numerical integration technique.
# 4. Repeat steps 2-3 until the ball reaches the ground (i.e., its height is approximately zero).
#
# Here's some Python code to simulate this:
#
# ```python
# import numpy as np
#
# def calculate_max_height(v0, g):
#     # Define constants
#     dt = 0.01  # time step
#     t_max = float('inf')  # initial maximum time
#     t_current = 0  # current time
#     v_current = v0  # current velocity
#     h_current = 0  # current height
#
#     while True:
#         # Calculate acceleration at the current time step
#         a = -g * dt
#
#         # Update velocity and position using Euler's method
#         v_next = v_current + a * dt
#         h_next = h_current + v_current * dt
#
#         # Check if the ball has reached the ground
#         if np.isclose(h_next, 0):
#             break
#
#         # Update variables for the next time step
#         t_next = t_current + dt
#         v_current = v_next
#         h_current = h_next
#         t_current = t_next
#
#     return h_current
#
# v0 = 20  # initial velocity in m/s
# g = -9.81  # gravity acceleration in m/s^2
#
# max_height = calculate_max_height(v0, g)
# print(f"The ball will reach a maximum height of {np.round(max_height, 2)} meters.")
# ```
#
# **Note:** This code uses numerical integration to simulate the motion of the ball over time. It assumes that the ball's motion is continuous and neglects air resistance, which can affect the actual height reached by the ball.

# %% [markdown]
# ## Aggregating Results

# %%
def aggregate_results(paths):
    """
    Aggregate results from multiple reasoning paths.
    
    Args:
    paths (list): List of reasoning paths.
    
    Returns:
    str: The most consistent answer.
    """
    prompt_template = PromptTemplate(
        input_variables=["paths"],
        template="""Analyze the following reasoning paths and determine the most consistent answer. If there are discrepancies, explain why and provide the most likely correct answer.
        Reasoning paths:
        {paths}
        
        Most consistent answer:"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"paths": "\n".join(paths)}).content
    return response

# %%
aggregated_result = aggregate_results(paths)
print("Aggregated Result:\n", aggregated_result)
# Out:
# Aggregated Result:
#  The most consistent answer for the maximum height reached by the ball is approximately 20.41 meters.
#
# This answer was obtained using a unique approach involving numerical integration to simulate the motion of the ball over time. The code provided uses Euler's method to update the velocity and position of the ball at each time step, taking into account the acceleration due to gravity.
#
# While the other reasoning paths are creative and insightful, they do not lead to an accurate solution for the maximum height reached by the ball. The original problem statement does not provide enough information to solve the problem using standard physics formulas, but numerical integration provides a reliable method for simulating the motion of the ball under constant acceleration due to gravity.
#
# The value of 20.41 meters is calculated using the equation derived from the time of flight and the relationship between velocity, acceleration, and displacement:
#
# H_max = v0^2 / (2 * g)
#
# Substituting the given initial velocity of 20 m/s and the gravity acceleration (-9.81 m/s^2), we get:
#
# H_max = (20^2) / (2 * -9.81)
# = 400 / (-19.6)
# ≈ 20.41 meters

# %% [markdown]
# ## Self-Consistency Check

# %%
def self_consistency_check(problem, aggregated_result):
    """
    Perform a self-consistency check on the aggregated result.
    
    Args:
    problem (str): The original problem statement.
    aggregated_result (str): The aggregated result to check.
    
    Returns:
    str: An evaluation of the result's consistency and reliability.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "result"],
        template="""Evaluate the consistency and reliability of the following result for the given problem.
        Problem: {problem}
        Result: {result}
        
        Evaluation (consider factors like logical consistency, adherence to known facts, and potential biases):"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"problem": problem, "result": aggregated_result}).content
    return response

# %%
consistency_evaluation = self_consistency_check(problem, aggregated_result)
print("Self-Consistency Evaluation:\n", consistency_evaluation)
# Out:
# Self-Consistency Evaluation:
#  Based on the provided information, I would evaluate the result as reliable but with some caveats.
#
# **Logical Consistency:** The result is based on a specific equation derived from the time of flight and the relationship between velocity, acceleration, and displacement. This approach is consistent with the laws of physics governing projectile motion.
#
# **Adherence to Known Facts:** The use of Euler's method for numerical integration is sound, assuming that the simulation parameters (e.g., initial velocity, gravity) are correctly defined and that the time step is small enough to accurately capture the dynamics of the ball. The equation H_max = v0^2 / (2 * g) is also a well-established formula in physics.
#
# **Potential Biases:**
#
# 1. **Simplifications:** Euler's method may not provide an accurate solution for very short or long time periods, due to numerical instability or convergence issues. Additionally, the simulation assumes a constant acceleration due to gravity, which might not hold true in reality due to atmospheric drag and other external factors.
# 2. **Initial Conditions:** The initial velocity of 20 m/s is assumed to be accurate. However, small errors in this value could propagate through the simulation, affecting the result.
# 3. **Gravity Value:** The value of -9.81 m/s^2 for gravity might not be exactly accurate, as it depends on the location and atmospheric conditions.
#
# **Reliability Assessment:**
#
# Given the assumptions and potential biases, I would rate the reliability of the result as high (8/10). However, to ensure accuracy, it's essential to:
#
# 1. Validate the simulation parameters and initial conditions.
# 2. Use more sophisticated numerical methods, such as Runge-Kutta or Verlet integration, which can provide better accuracy and stability for longer time periods.
# 3. Consider additional factors like atmospheric drag and air resistance to improve the realism of the simulation.
#
# Overall, while the result is based on a sound physical principle, it's crucial to acknowledge the limitations and potential biases inherent in numerical simulations.

# %% [markdown]
# ## Tackling Different Types of Problem using this method

# %% [markdown]
# ### General Defination of Our Solution

# %%
def solve_problem(problem):
    """
    Solve a problem using multiple reasoning paths, aggregation, and self-consistency check.
    
    Args:
    problem (str): The problem statement.
    
    Returns:
    tuple: (aggregated_result, consistency_evaluation)
    """
    paths = generate_multiple_paths(problem)
    aggregated_result = aggregate_results(paths)
    consistency_evaluation = self_consistency_check(problem, aggregated_result)
    return aggregated_result, consistency_evaluation

# %%
# Example problems
problems = [
    "What is the capital of France?",
    "Explain the concept of supply and demand in economics.",
    "If a train travels at 60 km/h, how long will it take to cover 180 km?"
]

for problem in problems:
    print(f"Problem: {problem}")
    result, evaluation = solve_problem(problem)
    print("Aggregated Result:\n", result)
    print("\nConsistency Evaluation:\n", evaluation)
    print("\n" + "-"*50 + "\n")
# Out:
# Problem: What is the capital of France?
# Aggregated Result:
#  This problem statement appears to be an incomplete and humorous exercise in creativity rather than a genuine mathematical or logical puzzle. The various steps outlined are whimsical and unrelated to the actual question of finding the capital of France.
#
# The first "reasoning path" provided seems to involve nonsensical concepts, such as a giant eggplant representing French cuisine, snails carrying Eiffel Towers, and a French onion named Pierre unlocking ancient secrets. This approach is clearly not meant to be taken seriously.
#
# The second part of the prompt presents a fictional detective scenario that involves solving a mystery related to a famous French person. The steps outlined in this scenario are also creative but ultimately pointless, as they do not provide any logical or mathematical solutions to finding the capital of France.
#
# Given the nature of these two scenarios, it's difficult to pinpoint a single "most consistent answer." However, if we had to identify a thread that connects both approaches, it would be the use of creative and unconventional thinking. In other words, both paths demonstrate an attempt to find novel solutions by combining unrelated concepts in innovative ways.
#
# That being said, neither approach yields a logical or mathematically sound solution to finding the capital of France. The most "consistent" answer would likely be something like:
#
# The capital of France is Paris.
#
# This answer is straightforward and widely accepted, yet it doesn't rely on the creative (or uncreative) thinking presented in the original problem statement.
#
# Consistency Evaluation:
#  Based on the evaluation provided, I would rate the result as inconsistent, unreliable, and potentially biased. Here's why:
#
# 1. Lack of logical consistency: Both "reasoning paths" presented in the problem statement are creative and whimsical, but they do not provide any logical or mathematical solutions to finding the capital of France.
# 2. Adherence to known facts: The problem statement does not adhere to any known facts about France or its capital. The use of fictional elements, such as a giant eggplant representing French cuisine, is not grounded in reality.
# 3. Potential biases: The problem statement's reliance on creative and unconventional thinking may introduce personal biases or subjective interpretations, which can lead to inconsistent results.
#
# The provided "most consistent" answer, stating that the capital of France is Paris, is based on widely accepted facts and does not rely on creative or unconventional thinking. This answer is more reliable and logical than the approaches presented in the problem statement.
#
# Overall, I would rate the result as follows:
#
# * Consistency: 0/10 (due to lack of logical consistency)
# * Reliability: 0/10 (due to reliance on fictional elements and subjective interpretations)
# * Adherence to known facts: 0/10 (due to lack of adherence to known facts about France or its capital)
#
# The most consistent answer, stating that the capital of France is Paris, would receive a rating of:
#
# * Consistency: 10/10
# * Reliability: 9/10 (based on widely accepted facts)
# * Adherence to known facts: 10/10
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  The most consistent answer is based on the analysis of the provided reasoning paths. Both explanations use a narrative structure to illustrate the concept of supply and demand, making them more engaging and easier to understand.
#
# However, there are some discrepancies between the two explanations:
#
# 1.  In the music festival example, the supply curve is depicted as being limited by the ticket vendors holding back their tickets. However, in the story about the fishermen, the reduced supply is attributed to Leo's damaged equipment and Sammy's investment in new gear.
# 2.  The tale of the fishermen also introduces a factor not present in the music festival explanation: the role of technological advantages. This highlights the importance of innovation and adaptation in the context of supply and demand.
# 3.  In both explanations, the equilibrium point is described as occurring when the supply and demand curves intersect. However, the specific details surrounding this equilibrium differ between the two examples.
#
# Despite these discrepancies, both explanations aim to convey the same core message: that supply and demand interact to determine market outcomes. The unique approaches used in each explanation make them more memorable and engaging for readers.
#
# The most likely correct answer is that the concept of supply and demand is a fundamental principle in economics that explains how markets work. It is essential to understand this concept to predict market trends, make informed decisions about resource allocation, and optimize economic activities.
#
# In conclusion, while there are some discrepancies between the two explanations, they both contribute to our understanding of supply and demand and their role in shaping market outcomes.
#
# Consistency Evaluation:
#  Overall, the result is generally reliable and consistent with economic principles. However, there are some areas that require evaluation:
#
# Strengths:
#
# 1.  The explanations use a narrative structure, making them more engaging and easier to understand.
# 2.  Both explanations convey the same core message about supply and demand interacting to determine market outcomes.
# 3.  The unique approaches used in each explanation make them memorable and engaging for readers.
#
# Weaknesses:
#
# 1.  Discrepancies between the two explanations: The music festival example portrays the supply curve as limited by ticket vendors, while the fishermen story attributes reduced supply to equipment damage and investment. This inconsistency might lead to confusion.
# 2.  Lack of explicit mention of market forces like scarcity, opportunity cost, or price mechanisms, which are fundamental aspects of supply and demand analysis.
# 3.  Potential bias in interpretation: The explanations focus on storytelling and narrative structure rather than providing a comprehensive, step-by-step explanation of the supply and demand concept.
#
# To improve the reliability and consistency of the result, it would be helpful to:
#
# 1.  Clarify and reconcile the discrepancies between the two explanations.
# 2.  Provide more explicit information about market forces and mechanisms involved in supply and demand analysis.
# 3.  Adopt a more objective tone and avoid narrative embellishments that might introduce bias.
#
# By addressing these weaknesses, the result can provide a clearer, more comprehensive understanding of the concept of supply and demand in economics.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
# Aggregated Result:
#  After analyzing all three reasoning paths, I found the most consistent answer to be path 1 (the storytelling approach). Here's why:
#
# * Path 2 is incorrect because it assumes that time can be calculated using a simple division of distance by speed. However, this ignores the fact that the train is moving in two directions simultaneously, which is mentioned in the initial paragraph.
# * Path 3 is incorrect because it implies that time can be measured by counting the number of hours it takes to pass certain landmarks or segments (Cluck Norris, tea with villagers, navigating around the "No Locomotives Allowed" sign). While this approach makes time more relatable and engaging, it doesn't accurately calculate the total travel time.
#
# In contrast, path 1 uses a creative non-mathematical method called storytelling to break down time into smaller segments. The story creates a narrative that is proportional to the speed of the train (60 km/h) and the distance (180 km). By analyzing the storytelling approach, we can infer that it attempts to convert the numerical problem into an engaging and memorable experience.
#
# While path 1's answer might not be precise, its use of creative problem-solving and narrative storytelling makes it a more consistent approach than paths 2 and 3.
#
# Consistency Evaluation:
#  The evaluation of the result is as follows:
#
# **Logical Consistency:** The evaluation's analysis of the three reasoning paths shows that Path 1 is considered the most consistent answer because it attempts to convert a numerical problem into an engaging narrative. However, this approach raises questions about the logical consistency of the story itself. How does the speed of 60 km/h and distance of 180 km translate into a relatable and accurate storytelling experience? The evaluation acknowledges that Path 1's answer might not be precise but emphasizes its use of creative problem-solving.
#
# **Adherence to Known Facts:** The result does not explicitly demonstrate an understanding of known facts related to the train's travel time, such as the concept of speed units (e.g., kilometers per hour), the relationship between distance and speed, or the actual calculation for determining travel time. The evaluation ignores these fundamental concepts in favor of creative storytelling.
#
# **Potential Biases:** The result appears to be influenced by a subjective preference for Path 1 over Paths 2 and 3, which may indicate potential biases. The evaluation prioritizes the use of storytelling as a creative problem-solving approach over more traditional methods that adhere to established mathematical principles.
#
# In conclusion, while the evaluation highlights the engaging nature of Path 1's storytelling approach, it also raises concerns about logical consistency, adherence to known facts, and potential biases. A more reliable result would require a deeper understanding of mathematical concepts related to speed, distance, and time, as well as a more objective evaluation of different problem-solving strategies.
#
# A more accurate calculation for the train's travel time can be obtained using traditional methods:
#
# Travel Time = Distance / Speed
# = 180 km / 60 km/h
# = 3 hours
#
# This result is based on established mathematical principles and does not rely on creative storytelling.
#
# --------------------------------------------------

# %% [markdown]
# # Constrained and Guided Generation

# %%
def display_output(output):
    """Display the model's output in a formatted manner."""
    print("Model Output:")
    print("-" * 40)
    print(output)
    print("-" * 40)
    print()

# %%
constrained_prompt = PromptTemplate(
    input_variables=["product", "target_audience", "tone", "word_limit"],
    template="""Create a product description for {product} targeted at {target_audience}.
    Use a {tone} tone and keep it under {word_limit} words.
    The description should include:
    1. A catchy headline
    2. Three key features
    3. A call to action
    
    Product Description:
    """
)

# Generate the constrained output
input_variables = {
    "product": "smart water bottle",
    "target_audience": "health-conscious millennials",
    "tone": "casual and friendly",
    "word_limit": "75"
}

chain = constrained_prompt | llm
output = chain.invoke(input_variables).content
display_output(output)
# Out:
# Model Output:
# ----------------------------------------
# **Hydrate Your Way to Happiness**
#
# Stay on top of your game with our smart water bottle!
#
# • **Track Your Hydration**: Monitor your daily water intake and set reminders to drink up.
# • **Filter Freshness**: Enjoy filtered water every time, no more weird tastes or odors!
# • **Fit Your Style**: Customize your bottle with interchangeable sleeves and colors.
#
# Get yours now and make hydration a breeze!
# ----------------------------------------

# %% [markdown]
# ## Implementing Rule-Based Generation

# %%
job_posting_prompt = PromptTemplate(
    input_variables=["job_title", "company", "location", "experience"],
    template="""Create a job posting for a {job_title} position at {company} in {location}.
    The candidate should have {experience} years of experience.
    Follow these rules:
    1. Start with a brief company description (2 sentences)
    2. List 5 key responsibilities, each starting with an action verb
    3. List 5 required qualifications, each in a single sentence
    4. End with a standardized equal opportunity statement
    
    Format the output as follows:
    COMPANY: [Company Description]
    
    RESPONSIBILITIES:
    - [Responsibility 1]
    - [Responsibility 2]
    - [Responsibility 3]
    - [Responsibility 4]
    - [Responsibility 5]
    
    QUALIFICATIONS:
    - [Qualification 1]
    - [Qualification 2]
    - [Qualification 3]
    - [Qualification 4]
    - [Qualification 5]
    
    EEO: [Equal Opportunity Statement]
    """
)

# Generate the rule-based output
input_variables = {
    "job_title": "Senior Software Engineer",
    "company": "TechInnovate Solutions",
    "location": "San Francisco, CA",
    "experience": "5+"
}

chain = job_posting_prompt | llm
output = chain.invoke(input_variables).content
display_output(output)
# Out:
# Model Output:
# ----------------------------------------
# COMPANY: TechInnovate Solutions is a leading technology firm in San Francisco, CA, specializing in innovative software solutions for various industries. We are committed to fostering a collaborative and dynamic work environment that encourages creativity and growth.
#
# RESPONSIBILITIES:
#
# - Design and develop complex software systems that meet the needs of our clients
# - Collaborate with cross-functional teams to identify project requirements and deliver high-quality solutions
# - Lead code reviews, provide technical guidance, and mentor junior engineers to ensure consistency and excellence in coding standards
# - Analyze and resolve complex software issues, providing timely and effective support to internal stakeholders
# - Develop and maintain technical documentation, ensuring that all systems are well-documented for future maintenance and updates
#
# QUALIFICATIONS:
#
# - Possess at least 5+ years of experience as a senior software engineer with a proven track record of delivering high-quality solutions
# - Hold a Bachelor's degree in Computer Science or related field from an accredited institution
# - Have extensive experience with modern programming languages, including Java, Python, and C++
# - Proven expertise in agile development methodologies, such as Scrum and Kanban
# - Strong understanding of cloud-based technologies, including AWS or Azure
#
# EEO: TechInnovate Solutions is an equal opportunity employer and welcomes applications from diverse candidates. We are committed to creating an inclusive work environment that values diversity, equity, and inclusion.
# ----------------------------------------

# %% [markdown]
# ## Using Regex Parser for Structured Output

# %%
# Define a regex parser for structured output
regex_parser = RegexParser(
    regex=r"COMPANY:\s*([\s\S]*?)\n\s*RESPONSIBILITIES:\s*([\s\S]*?)\n\s*QUALIFICATIONS:\s*([\s\S]*?)\n\s*EEO:\s*([\s\S]*)",
    output_keys=["company_description", "responsibilities", "qualifications", "eeo_statement"]
)
# This regex pattern captures the company description, responsibilities, qualifications, and EEO statement from the output text.

# Create a new prompt template that includes the parser instructions
parsed_job_posting_prompt = PromptTemplate(
    input_variables=["job_title", "company", "location", "experience"],
    template="""Create a job posting for a {job_title} position at {company} in {location}.
    The candidate should have {experience} years of experience.
    Follow these rules:
    1. Start with a brief company description (2 sentences)
    2. List 5 key responsibilities, each starting with an action verb
    3. List 5 required qualifications, each in a single sentence
    4. End with a standardized equal opportunity statement
    
    Format the output EXACTLY as follows:
    COMPANY: [Company Description]
    
    RESPONSIBILITIES:
    - [Responsibility 1]
    - [Responsibility 2]
    - [Responsibility 3]
    - [Responsibility 4]
    - [Responsibility 5]
    
    QUALIFICATIONS:
    - [Qualification 1]
    - [Qualification 2]
    - [Qualification 3]
    - [Qualification 4]
    - [Qualification 5]
    
    EEO: [Equal Opportunity Statement]
    """
)

def clean_output(output):
    for key, value in output.items():
        if isinstance(value, str):
            # Remove leading/trailing whitespace and normalize newlines
            output[key] = re.sub(r'\n\s*', '\n', value.strip())
    return output

# Generate the parsed output
chain = parsed_job_posting_prompt | llm
raw_output = chain.invoke(input_variables).content

# Parse and clean the output
parsed_output = regex_parser.parse(raw_output)
cleaned_output = clean_output(parsed_output)

# Display the parsed output
print("Parsed Output:")
for key, value in cleaned_output.items():
    print(f"{key.upper()}:")
    print(value)
    print()
# Out:
# Parsed Output:
# COMPANY_DESCRIPTION:
# TechInnovate Solutions is a leading software development company in San Francisco, CA, dedicated to delivering innovative solutions to the tech industry. We are committed to fostering a collaborative and dynamic work environment that empowers our employees to grow and thrive.
#
# RESPONSIBILITIES:
# - Design and implement complex software systems that meet business requirements
# - Collaborate with cross-functional teams to identify and prioritize project goals and objectives
# - Develop and maintain cutting-edge technologies, including machine learning algorithms and data analytics tools
# - Mentor junior engineers and provide technical guidance to ensure seamless knowledge transfer
# - Conduct thorough code reviews and implement coding standards to ensure high-quality software delivery
#
# QUALIFICATIONS:
# - Possess at least 5+ years of experience in software development, with a focus on backend programming languages such as Java or Python.
# - Hold a Bachelor's degree in Computer Science or related field; Master's degree preferred.
# - Proven track record of leading complex projects and delivering results-driven solutions under tight deadlines.
# - Expertise in cloud-based technologies, including AWS or Azure, is highly desirable.
# - Excellent communication skills, with experience in presenting technical concepts to both technical and non-technical stakeholders.
#
# EEO_STATEMENT:
# TechInnovate Solutions is an equal opportunity employer committed to diversity, equity, and inclusion. We welcome applications from talented individuals of all backgrounds and perspectives.

# %% [markdown]
# ## Implementing Additional Constraints

# %%
review_prompt = PromptTemplate(
    input_variables=["product", "rating", "pros", "cons", "word_limit"],
    template="""Write a product review for {product} with the following constraints:
    1. The review should have a {rating}-star rating (out of 5)
    2. Include exactly {pros} pros and {cons} cons
    3. Use between 2 and 3 sentences for each pro and con
    4. The entire review should be under {word_limit} words
    5. End with a one-sentence recommendation
    
    Format the review as follows:
    Rating: [X] out of 5 stars
    
    Pros:
    1. [Pro 1]
    2. [Pro 2]
    ...
    
    Cons:
    1. [Con 1]
    2. [Con 2]
    ...
    
    Recommendation: [One-sentence recommendation]
    """
)

# Generate the constrained review
input_variables = {
    "product": "Smartphone X",
    "rating": "4",
    "pros": "3",
    "cons": "2",
    "word_limit": "200"
}

chain = review_prompt | llm
output = chain.invoke(input_variables).content
display_output(output)
# Out:
# Model Output:
# ----------------------------------------
# Rating: 4 out of 5 stars
#
# Pros:
#
# 1. The Smartphone X's camera is exceptional, capturing vibrant colors and detailed images even in low-light conditions.
# 2. The device's battery life is impressive, lasting a full day with moderate use.
# 3. The phone's sleek design and premium materials make it a stylish addition to any collection.
#
# Cons:
#
# 1. The Smartphone X's price point may be out of reach for budget-conscious buyers.
# 2. Some users have reported issues with the phone's fingerprint recognition system, requiring multiple attempts to unlock.
#
# Recommendation: Overall, the Smartphone X is a solid choice for those seeking a high-quality smartphone without breaking the bank, but its limitations in this regard prevent it from reaching its full potential.
# ----------------------------------------

# %% [markdown]
# # Role Prompting
# assign specific roles to AI models

# %% [markdown]
# ## Basic Role Assignment

# %%
tech_writer_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""You are a technical writer specializing in creating clear and concise documentation for software products.
    Your task is to write a brief explanation of {topic} for a user manual.
    Please provide a 2-3 sentence explanation that is easy for non-technical users to understand."""
)

chain = tech_writer_prompt | llm
response = chain.invoke({"topic": "cloud computing"})
print(response.content)
# Out:
# Here's a possible explanation:
#
# "Cloud computing allows you to store, manage, and access your data and applications over the internet, rather than on a local computer or server. This means that instead of having to manage your own hardware and software, you can use cloud-based services like storage, processing power, and software applications on-demand. By using cloud computing, you can easily scale up or down to meet changing needs, and access your files and data from anywhere with an internet connection."

# %% [markdown]
# ## Crafting Effective Role Descriptions

# %%
financial_advisor_prompt = PromptTemplate(
    input_variables=["client_situation"],
    template="""You are a seasoned financial advisor with over 20 years of experience in personal finance, investment strategies, and retirement planning.
    You have a track record of helping clients from diverse backgrounds achieve their financial goals.
    Your approach is characterized by:
    1. Thorough analysis of each client's unique financial situation
    2. Clear and jargon-free communication of complex financial concepts
    3. Ethical considerations in all recommendations
    4. A focus on long-term financial health and stability

    Given the following client situation, provide a brief (3-4 sentences) financial advice:
    {client_situation}

    Your response should reflect your expertise and adhere to your characteristic approach."""
)

chain = financial_advisor_prompt | llm
response = chain.invoke({"client_situation": "A 35-year-old professional earning $80,000 annually, with $30,000 in savings, no debt, and no retirement plan."})
print(response.content)
# Out:
# Based on the client's situation, I would recommend that they prioritize building an emergency fund, aiming to save 3-6 months' worth of expenses in a readily accessible savings account. Next, I would suggest exploring employer-matched retirement accounts, such as a 401(k) or IRA, to take advantage of compound interest and tax benefits. Considering their relatively high income-to-expenses ratio, I would also encourage the client to explore tax-efficient investment strategies, such as index fund investing, to optimize returns while minimizing taxes. By taking these steps, the client can establish a solid financial foundation for long-term stability and success.

# %% [markdown]
# ## Comparision of Roles

# %%
roles = [
    ("Scientist", "You are a research scientist specializing in climate change. Explain the following concept in scientific terms:"),
    ("Teacher", "You are a middle school science teacher. Explain the following concept in simple terms suitable for 12-year-old students:"),
    ("Journalist", "You are a journalist writing for a popular science magazine. Explain the following concept in an engaging and informative manner for a general adult audience:")
]

topic = "The greenhouse effect"

for role, description in roles:
    role_prompt = PromptTemplate(
        input_variables=["topic"],
        template=f"{description} {{topic}}"
    )
    chain = role_prompt | llm
    response = chain.invoke({"topic": topic})
    print(f"\n{role}'s explanation:\n")
    print(response.content)
    print("-" * 50)
# Out:
# Scientist's explanation:
#
# The greenhouse effect is a complex process by which certain gases in the Earth's atmosphere trap heat from the sun, leading to a warming of the planet. This natural phenomenon has been occurring for millions of years and plays a crucial role in maintaining the Earth's temperature.
#
# **Mechanism:**
#
# The greenhouse effect occurs when solar radiation enters the Earth's atmosphere and is absorbed by the surface, including oceans, land, and ice. This absorbed energy is then re-radiated back into the atmosphere as infrared (IR) radiation, which is less energetic than the original solar radiation. The IR radiation is trapped by certain gases in the atmosphere, such as water vapor (H2O), carbon dioxide (CO2), methane (CH4), and others.
#
# These greenhouse gases have a molecular structure that allows them to absorb IR radiation at specific wavelengths. As they absorb the energy, their molecules vibrate or rotate, which increases their temperature. The trapped heat is then redistributed throughout the atmosphere through convection and conduction processes.
#
# **Greenhouse Gases:**
#
# There are several key greenhouse gases that contribute to the greenhouse effect:
#
# 1. Water vapor (H2O): The most abundant greenhouse gas in the atmosphere.
# 2. Carbon dioxide (CO2): Released from fossil fuel burning, land use changes, and natural sources such as volcanoes.
# 3. Methane (CH4): Released from agriculture, natural gas production and transport, and landfills.
# 4. Nitrous oxide (N2O): Released from agricultural activities, industrial processes, and fossil fuel burning.
# 5. Fluorinated gases (F-gases): Used in refrigeration systems, air conditioning, and electrical equipment.
#
# **Role of the Greenhouse Effect:**
#
# The greenhouse effect is essential for maintaining a habitable Earth. It:
#
# 1. Regulates the planet's temperature: By trapping heat and maintaining a stable global climate.
# 2. Supports life: The greenhouse effect allows plants to undergo photosynthesis, which is essential for primary production and food chains.
#
# **Human Impact on the Greenhouse Effect:**
#
# However, human activities have significantly increased the concentration of greenhouse gases in the atmosphere, leading to an enhanced greenhouse effect:
#
# 1. Fossil fuel burning: Releases large amounts of CO2 into the atmosphere.
# 2. Land use changes: Deforestation, urbanization, and other land-use changes lead to soil carbon emissions and increased atmospheric CO2.
# 3. Agricultural activities: Methane emissions from agriculture contribute to the enhanced greenhouse effect.
#
# **Consequences:**
#
# The enhanced greenhouse effect has significant consequences for the Earth's climate:
#
# 1. Global warming: Rising temperatures due to increased atmospheric CO2 and other greenhouse gases.
# 2. Sea-level rise: Melting of glaciers and ice sheets contributes to sea-level rise.
# 3. Extreme weather events: Changes in atmospheric circulation patterns lead to more frequent and intense heatwaves, droughts, and heavy precipitation events.
#
# **Conclusion:**
#
# The greenhouse effect is a complex process by which certain gases in the Earth's atmosphere trap heat from the sun, leading to a warming of the planet. Human activities have significantly increased the concentration of greenhouse gases, enhancing the natural greenhouse effect and leading to global warming and associated climate change impacts.
# --------------------------------------------------
#
# Teacher's explanation:
#
# Hello, class! Today we're going to talk about something really cool called the greenhouse effect.
#
# So, you know how sometimes it gets really hot outside during the summer? That's because the sun is shining down on us and heating up the Earth. But did you know that the Earth actually has a special blanket around it that helps keep it warm?
#
# This blanket is made up of gases in the air, like carbon dioxide and water vapor. When these gases trap heat from the sun, they create a kind of "greenhouse" effect.
#
# Think of it like this: imagine you're standing outside on a sunny day, wearing a big coat to keep yourself warm. That's kind of what the greenhouse effect is – the Earth's blanket keeps the heat in and the cold out.
#
# Now, here's the thing: just like how your coat can get too hot if you wear it for too long, the Earth's blanket gets too hot sometimes because of all the pollution we put into the air. This means that the heat can't escape properly, and that makes our planet even hotter.
#
# But don't worry! The greenhouse effect is a natural process that helps keep us warm in the winter months when it's cold outside. It's just that we need to be careful not to make it too hot by releasing bad stuff into the air.
#
# So, what can we do? Well, one way is to reduce our carbon footprint and use cleaner energy sources like solar and wind power. We can also plant more trees and take care of our air so that it doesn't get too polluted.
#
# That's a lot to think about, I know! But remember, every small action we take can help make a big difference in keeping our planet happy and healthy.
# --------------------------------------------------
#
# Journalist's explanation:
#
# **The Greenhouse Effect: How Earth's Atmosphere Keeps Us Warm**
#
# As we step outside on a chilly morning, the warmth of the sun hits us like a gentle hug. But have you ever wondered how our planet manages to retain that heat and keep us cozy? It all comes down to something called the greenhouse effect.
#
# **What is the Greenhouse Effect?**
#
# The greenhouse effect is like a natural thermostat for our Earth. It's the process by which certain gases in our atmosphere trap heat from the sun, keeping the planet warm enough to support life as we know it. Think of it like a big blanket that wraps around the Earth, trapping warmth and preventing it from escaping into space.
#
# **How Does it Work?**
#
# Here's how it works: when the sun shines on the Earth, it heats up the surface. This heat is then absorbed by gases in the atmosphere, such as carbon dioxide, methane, and water vapor. These gases act like a blanket, trapping the heat and preventing it from escaping into space.
#
# The greenhouse effect is similar to what happens in your car on a cold day. You turn off the engine, but you still feel warm inside because the air in the car has been heated up by the sun's rays. The same thing happens with the Earth – the atmosphere acts like a warm blanket, keeping us cozy even when the outside temperature drops.
#
# **But Why is it a Problem?**
#
# So why do we care about this natural process? Well, human activities like burning fossil fuels and deforestation have released massive amounts of greenhouse gases into the atmosphere. This has amplified the greenhouse effect, leading to global warming and climate change.
#
# Imagine the blanket around the Earth getting thicker and thicker – that's essentially what's happening with rising temperatures and extreme weather events. It's a natural process that's been occurring for millions of years, but human activities have accelerated it to alarming levels.
#
# **The Impact on Our Planet**
#
# So what does this mean for our planet? Rising temperatures are causing melting ice caps, sea-level rise, and more frequent extreme weather events like hurricanes and wildfires. It's not just about the polar bears – climate change affects us all, from our food supply to our daily lives.
#
# But don't worry! There's still hope. By reducing our carbon footprint, investing in renewable energy sources, and adopting sustainable practices, we can slow down the greenhouse effect and give our planet a chance to recover.
#
# **Take Action**
#
# So what can you do today? Here are some simple steps:
#
# * Use public transport or bike whenever possible
# * Switch to energy-efficient light bulbs and appliances
# * Reduce meat consumption and adopt plant-based diets
# * Conserve water and reduce waste
#
# Every small action counts, and together we can make a difference.
#
# **Conclusion**
#
# The greenhouse effect is like a delicate balance – too much heat and our planet gets too hot. But with knowledge comes power, and by understanding how this natural process works, we can take steps to mitigate its effects. It's time to get cozy with the Earth and work towards a more sustainable future for all.
# --------------------------------------------------

# %% [markdown]
# ## Refining Role Descriptions
# Let's take story telling examples.

# %%
storyteller_prompt = PromptTemplate(
    input_variables=["style", "scenario"],
    template="""You are a master storyteller known for your ability to adapt to various narrative styles.
    Your current task is to write in the style of {style}.
    Key characteristics of this style include:
    1. {style_char1}
    2. {style_char2}
    3. {style_char3}

    Write a short paragraph (3-4 sentences) in this style about the following scenario:
    {scenario}

    Ensure your writing clearly reflects the specified style."""
)

styles = [
    {
        "name": "Gothic horror",
        "char1": "Atmospheric and ominous descriptions",
        "char2": "Themes of decay, death, and the supernatural",
        "char3": "Heightened emotions and sense of dread"
    },
    {
        "name": "Minimalist realism",
        "char1": "Sparse, concise language",
        "char2": "Focus on everyday, ordinary events",
        "char3": "Subtle implications rather than explicit statements"
    }
]

scenario = "A person enters an empty house at twilight"

for style in styles:
    chain = storyteller_prompt | llm
    response = chain.invoke({
        "style": style["name"],
        "style_char1": style["char1"],
        "style_char2": style["char2"],
        "style_char3": style["char3"],
        "scenario": scenario
    })
    print(f"\n{style['name']} version:\n")
    print(response.content)
    print("-" * 50)
# Out:
# Gothic horror version:
#
# As the last wisps of sunlight surrendered to the encroaching twilight, Emilia stepped across the threshold of Ravenswood Manor, her footsteps echoing through the vacant halls like a mournful sigh. The once-grand entrance, now shrouded in a tapestry of grime and decay, seemed to yawn open like a cold, dead mouth, revealing a cavernous expanse of shadows that stretched out before her like a dark, malevolent sea. The air within was heavy with the scent of rot and forgotten memories, and Emilia's heart quickened as she felt the weight of unseen eyes upon her, watching her every move with an unblinking gaze. In this forsaken house, time itself seemed to have grown still, waiting for some unseen force to stir once more.
# --------------------------------------------------
#
# Minimalist realism version:
#
# The door creaks, a slow protest as it yields to the turn of the handle. The interior is bathed in a faint, diffused light that seeps through worn curtains. A lone chair sits by the window, its presence a reminder of something left behind or set aside. In this stillness, shadows stretch and fold, like dark petals unfolding on an unseen flower.
# --------------------------------------------------
